# %% [markdown]
# # Synthetic Enron Email Experiment
# This notebook demonstrates the prototype pipeline.

# %%
import json
from pathlib import Path
from src.pipeline import generate

email = json.loads(Path('../data/sample/sample_email.json').read_text())
result = generate(email, offline=True)
print(result['synthetic'])

# %%
print('Detected entities:')
for e in result['detected_entities']:
    print(e['label'], '=>', e['text'])

# %%
print(json.dumps(result['validation'], indent=2))
